# %% [markdown]
# # Dhan Market Data Lab
# Use `data_querying` to fetch historical and intraday data from Dhan API.

# %%
import sys
sys.path.insert(0, '/app')

from data_querying import get_historical_data, get_intraminute_data
import pandas as pd
import pandas_ta as ta
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# Fetch historical data (security_id, exchange_segment, instrument_type, from_date, to_date)
silver = get_historical_data('21428', 'NSE_EQ', 'EQUITY', '2025-01-01', '2026-05-07')
silver.head()
